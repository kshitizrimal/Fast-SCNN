# %%
# !pip install tensorflow-gpu==2.0.0-alpha0

import tensorflow as tf
# Out:
# Collecting tensorflow-gpu==2.0.0-alpha0
#   Downloading https://files.pythonhosted.org/packages/1a/66/32cffad095253219d53f6b6c2a436637bbe45ac4e7be0244557210dc3918/tensorflow_gpu-2.0.0a0-cp36-cp36m-manylinux1_x86_64.whl (332.1MB)
#      |████████████████████████████████| 332.1MB 55kB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.7)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (3.7.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.1.0)
# Collecting google-pasta>=0.1.2 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/64/bb/f1bbc131d6294baa6085a222d29abadd012696b73dcbf8cf1bf56b9f082a/google_pasta-0.1.5-py3-none-any.whl (51kB)
#      |████████████████████████████████| 61kB 2.9MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.12.0)
# Collecting tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/13/82/f16063b4eed210dc2ab057930ac1da4fbe1e91b7b051a6c8370b401e6ae7/tf_estimator_nightly-1.14.0.dev2019030115-py2.py3-none-any.whl (411kB)
#      |████████████████████████████████| 419kB 9.5MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.9)
# Collecting tb-nightly<1.14.0a20190302,>=1.14.0a20190301 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/a9/51/aa1d756644bf4624c03844115e4ac4058eff77acd786b26315f051a4b195/tb_nightly-1.14.0a20190301-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 46.9MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.33.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.16.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-alpha0) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-alpha0) (41.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (0.15.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (3.1)
# Installing collected packages: google-pasta, tf-estimator-nightly, tb-nightly, tensorflow-gpu
# Successfully installed google-pasta-0.1.5 tb-nightly-1.14.0a20190301 tensorflow-gpu-2.0.0a0 tf-estimator-nightly-1.14.0.dev2019030115

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ![Fast-SCNN Architecture](https://github.com/DeepVoltaire/Fast-SCNN/raw/master/figures/fast-scnn.png)

# %% [markdown]
# #### Custom function for conv2d: conv_block

# %%
def conv_block(inputs, conv_type, kernel, kernel_size, strides, padding='same', relu=True):
  
  if(conv_type == 'ds'):
    x = tf.keras.layers.SeparableConv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)
  else:
    x = tf.keras.layers.Conv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)  
  
  x = tf.keras.layers.BatchNormalization()(x)
  
  if (relu):
    x = tf.keras.activations.relu(x)
  
  return x

# %% [markdown]
# ## Step 1: Learning to DownSample

# %%
# Input Layer
input_layer = tf.keras.layers.Input(shape=(2048, 1024, 3), name = 'input_layer')

# %%
lds_layer = conv_block(input_layer, 'conv', 32, (3, 3), strides = (2, 2))
lds_layer = conv_block(lds_layer, 'ds', 48, (3, 3), strides = (2, 2))
lds_layer = conv_block(lds_layer, 'ds', 64, (3, 3), strides = (2, 2))

# %% [markdown]
# ## Step 2: Global Feature Extractor

# %% [markdown]
# #### residual custom method

# %%
def _res_bottleneck(inputs, filters, kernel, t, s, r=False):
    
    
    tchannel = tf.keras.backend.int_shape(inputs)[-1] * t

    x = conv_block(inputs, 'conv', tchannel, (1, 1), strides=(1, 1))

    x = tf.keras.layers.DepthwiseConv2D(kernel, strides=(s, s), depth_multiplier=1, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = conv_block(x, 'conv', filters, (1, 1), strides=(1, 1), padding='same', relu=False)

    if r:
        x = tf.keras.layers.add([x, inputs])
    return x

# %% [markdown]
# #### Bottleneck custom method

# %%
def bottleneck_block(inputs, filters, kernel, t, strides, n):
  x = _res_bottleneck(inputs, filters, kernel, t, strides)
  
  for i in range(1, n):
    x = _res_bottleneck(x, filters, kernel, t, 1, True)

  return x

# %% [markdown]
# #### PPM Method

# %%
def pyramid_pooling_block(input_tensor, bin_sizes):
  concat_list = [input_tensor]
  w = 64
  h = 32

  for bin_size in bin_sizes:
    x = tf.keras.layers.AveragePooling2D(pool_size=(w//bin_size, h//bin_size), strides=(w//bin_size, h//bin_size))(input_tensor)
    x = tf.keras.layers.Conv2D(128, 3, 2, padding='same')(x)
    x = tf.keras.layers.Lambda(lambda x: tf.image.resize(x, (w,h)))(x)

    concat_list.append(x)

  return tf.keras.layers.concatenate(concat_list)

# %% [markdown]
# #### Assembling all the methods

# %%
gfe_layer = bottleneck_block(lds_layer, 64, (3, 3), t=6, strides=2, n=3)
gfe_layer = bottleneck_block(gfe_layer, 96, (3, 3), t=6, strides=2, n=3)
gfe_layer = bottleneck_block(gfe_layer, 128, (3, 3), t=6, strides=1, n=3)
gfe_layer = pyramid_pooling_block(gfe_layer, [2,4,6,8])

# %% [markdown]
# ## Step 3: Feature Fusion

# %%
ff_layer1 = conv_block(lds_layer, 'conv', 128, (1,1), padding='same', strides= (1,1), relu=False)

# %%
ff_layer2 = tf.keras.layers.UpSampling2D((4, 4))(gfe_layer)
ff_layer2 = tf.keras.layers.DepthwiseConv2D((3,3), strides=(1, 1), depth_multiplier=1, padding='same')(ff_layer2)
ff_layer2 = tf.keras.layers.BatchNormalization()(ff_layer2)
ff_layer2 = tf.keras.activations.relu(ff_layer2)
ff_layer2 = tf.keras.layers.Conv2D(128, 1, 1, padding='same', activation=None)(ff_layer2)

# %%
ff_final = tf.keras.layers.add([ff_layer1, ff_layer2])
ff_final = tf.keras.layers.BatchNormalization()(ff_final)
ff_final = tf.keras.activations.relu(ff_final)

# %% [markdown]
# ## Step 4: Classifier

# %%
classifier = tf.keras.layers.SeparableConv2D(128, (3, 3), padding='same', strides = (1, 1), name = 'DSConv1_classifier')(ff_final)
classifier = tf.keras.layers.BatchNormalization()(classifier)
classifier = tf.keras.activations.relu(classifier)

classifier = tf.keras.layers.SeparableConv2D(128, (3, 3), padding='same', strides = (1, 1), name = 'DSConv2_classifier')(classifier)
classifier = tf.keras.layers.BatchNormalization()(classifier)
classifier = tf.keras.activations.relu(classifier)


classifier = conv_block(classifier, 'conv', 19, (1, 1), strides=(1, 1), padding='same', relu=False)

classifier = tf.keras.layers.Dropout(0.3)(classifier)

classifier = tf.keras.layers.UpSampling2D((8, 8))(classifier)
classifier = tf.keras.activations.softmax(classifier)

# %% [markdown]
# ## Model Compilation

# %%
fast_scnn = tf.keras.Model(inputs = input_layer , outputs = classifier, name = 'Fast_SCNN')
optimizer = tf.keras.optimizers.SGD(momentum=0.9, lr=0.045)
fast_scnn.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
fast_scnn.summary()
# Out:
# Model: "Fast_SCNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 2048, 1024,  0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1024, 512, 32 896         input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_12 (Batc (None, 1024, 512, 32 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# Relu_12 (TensorFlowOpLayer)     [(None, 1024, 512, 3 0           batch_normalization_v2_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 512, 256, 48) 1872        Relu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_13 (Batc (None, 512, 256, 48) 192         separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# Relu_13 (TensorFlowOpLayer)     [(None, 512, 256, 48 0           batch_normalization_v2_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 256, 128, 64) 3568        Relu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_14 (Batc (None, 256, 128, 64) 256         separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# Relu_14 (TensorFlowOpLayer)     [(None, 256, 128, 64 0           batch_normalization_v2_14[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 128, 384 24960       Relu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_15 (Batc (None, 256, 128, 384 1536        conv2d_5[0][0]
# __________________________________________________________________________________________________
# Relu_15 (TensorFlowOpLayer)     [(None, 256, 128, 38 0           batch_normalization_v2_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 128, 64, 384) 3840        Relu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_16 (Batc (None, 128, 64, 384) 1536        depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# Relu_16 (TensorFlowOpLayer)     [(None, 128, 64, 384 0           batch_normalization_v2_16[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 64, 64)  24640       Relu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_17 (Batc (None, 128, 64, 64)  256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 64, 384) 24960       batch_normalization_v2_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_18 (Batc (None, 128, 64, 384) 1536        conv2d_7[0][0]
# __________________________________________________________________________________________________
# Relu_17 (TensorFlowOpLayer)     [(None, 128, 64, 384 0           batch_normalization_v2_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 128, 64, 384) 3840        Relu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_19 (Batc (None, 128, 64, 384) 1536        depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# Relu_18 (TensorFlowOpLayer)     [(None, 128, 64, 384 0           batch_normalization_v2_19[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 64, 64)  24640       Relu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_20 (Batc (None, 128, 64, 64)  256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 64, 64)  0           batch_normalization_v2_20[0][0]
#                                                                  batch_normalization_v2_17[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 64, 384) 24960       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_21 (Batc (None, 128, 64, 384) 1536        conv2d_9[0][0]
# __________________________________________________________________________________________________
# Relu_19 (TensorFlowOpLayer)     [(None, 128, 64, 384 0           batch_normalization_v2_21[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 128, 64, 384) 3840        Relu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_22 (Batc (None, 128, 64, 384) 1536        depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# Relu_20 (TensorFlowOpLayer)     [(None, 128, 64, 384 0           batch_normalization_v2_22[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 64, 64)  24640       Relu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_23 (Batc (None, 128, 64, 64)  256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 64, 64)  0           batch_normalization_v2_23[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 64, 384) 24960       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_24 (Batc (None, 128, 64, 384) 1536        conv2d_11[0][0]
# __________________________________________________________________________________________________
# Relu_21 (TensorFlowOpLayer)     [(None, 128, 64, 384 0           batch_normalization_v2_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 64, 32, 384)  3840        Relu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_25 (Batc (None, 64, 32, 384)  1536        depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# Relu_22 (TensorFlowOpLayer)     [(None, 64, 32, 384) 0           batch_normalization_v2_25[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 32, 96)   36960       Relu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_26 (Batc (None, 64, 32, 96)   384         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 32, 576)  55872       batch_normalization_v2_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_27 (Batc (None, 64, 32, 576)  2304        conv2d_13[0][0]
# __________________________________________________________________________________________________
# Relu_23 (TensorFlowOpLayer)     [(None, 64, 32, 576) 0           batch_normalization_v2_27[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 64, 32, 576)  5760        Relu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_28 (Batc (None, 64, 32, 576)  2304        depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# Relu_24 (TensorFlowOpLayer)     [(None, 64, 32, 576) 0           batch_normalization_v2_28[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 32, 96)   55392       Relu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_29 (Batc (None, 64, 32, 96)   384         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 32, 96)   0           batch_normalization_v2_29[0][0]
#                                                                  batch_normalization_v2_26[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 32, 576)  55872       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_30 (Batc (None, 64, 32, 576)  2304        conv2d_15[0][0]
# __________________________________________________________________________________________________
# Relu_25 (TensorFlowOpLayer)     [(None, 64, 32, 576) 0           batch_normalization_v2_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 64, 32, 576)  5760        Relu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_31 (Batc (None, 64, 32, 576)  2304        depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# Relu_26 (TensorFlowOpLayer)     [(None, 64, 32, 576) 0           batch_normalization_v2_31[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 32, 96)   55392       Relu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_32 (Batc (None, 64, 32, 96)   384         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 32, 96)   0           batch_normalization_v2_32[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 32, 576)  55872       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_33 (Batc (None, 64, 32, 576)  2304        conv2d_17[0][0]
# __________________________________________________________________________________________________
# Relu_27 (TensorFlowOpLayer)     [(None, 64, 32, 576) 0           batch_normalization_v2_33[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 64, 32, 576)  5760        Relu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_34 (Batc (None, 64, 32, 576)  2304        depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# Relu_28 (TensorFlowOpLayer)     [(None, 64, 32, 576) 0           batch_normalization_v2_34[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 32, 128)  73856       Relu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_35 (Batc (None, 64, 32, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 32, 768)  99072       batch_normalization_v2_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_36 (Batc (None, 64, 32, 768)  3072        conv2d_19[0][0]
# __________________________________________________________________________________________________
# Relu_29 (TensorFlowOpLayer)     [(None, 64, 32, 768) 0           batch_normalization_v2_36[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 64, 32, 768)  7680        Relu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_37 (Batc (None, 64, 32, 768)  3072        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# Relu_30 (TensorFlowOpLayer)     [(None, 64, 32, 768) 0           batch_normalization_v2_37[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 32, 128)  98432       Relu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_38 (Batc (None, 64, 32, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 32, 128)  0           batch_normalization_v2_38[0][0]
#                                                                  batch_normalization_v2_35[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 32, 768)  99072       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_39 (Batc (None, 64, 32, 768)  3072        conv2d_21[0][0]
# __________________________________________________________________________________________________
# Relu_31 (TensorFlowOpLayer)     [(None, 64, 32, 768) 0           batch_normalization_v2_39[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 64, 32, 768)  7680        Relu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_40 (Batc (None, 64, 32, 768)  3072        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# Relu_32 (TensorFlowOpLayer)     [(None, 64, 32, 768) 0           batch_normalization_v2_40[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 32, 128)  98432       Relu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_41 (Batc (None, 64, 32, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 32, 128)  0           batch_normalization_v2_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 2, 2, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 6, 6, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 8, 8, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 1, 1, 128)    147584      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 128)    147584      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 3, 3, 128)    147584      average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 128)    147584      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 64, 32, 128)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64, 32, 128)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 32, 128)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 32, 128)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 32, 640)  0           add_5[0][0]
#                                                                  lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 256, 128, 640 0           concatenate[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 256, 128, 640 10486400    up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_43 (Batc (None, 256, 128, 640 2560        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 128, 128 8320        Relu_14[0][0]
# __________________________________________________________________________________________________
# Relu_33 (TensorFlowOpLayer)     [(None, 256, 128, 64 0           batch_normalization_v2_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_42 (Batc (None, 256, 128, 128 512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 128, 128 82048       Relu_33[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 128, 128 0           batch_normalization_v2_42[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_44 (Batc (None, 256, 128, 128 512         add_6[0][0]
# __________________________________________________________________________________________________
# Relu_34 (TensorFlowOpLayer)     [(None, 256, 128, 12 0           batch_normalization_v2_44[0][0]
# __________________________________________________________________________________________________
# DSConv1_classifier (SeparableCo (None, 256, 128, 128 17664       Relu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_45 (Batc (None, 256, 128, 128 512         DSConv1_classifier[0][0]
# __________________________________________________________________________________________________
# Relu_35 (TensorFlowOpLayer)     [(None, 256, 128, 12 0           batch_normalization_v2_45[0][0]
# __________________________________________________________________________________________________
# DSConv2_classifier (SeparableCo (None, 256, 128, 128 17664       Relu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_46 (Batc (None, 256, 128, 128 512         DSConv2_classifier[0][0]
# __________________________________________________________________________________________________
# Relu_36 (TensorFlowOpLayer)     [(None, 256, 128, 12 0           batch_normalization_v2_46[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 128, 19) 2451        Relu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_47 (Batc (None, 256, 128, 19) 76          conv2d_29[0][0]
# __________________________________________________________________________________________________
# Relu_37 (TensorFlowOpLayer)     [(None, 256, 128, 19 0           batch_normalization_v2_47[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 128, 19) 0           Relu_37[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 2048, 1024, 1 0           dropout[0][0]
# __________________________________________________________________________________________________
# Max (TensorFlowOpLayer)         [(None, 2048, 1024,  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# sub (TensorFlowOpLayer)         [(None, 2048, 1024,  0           up_sampling2d_1[0][0]
#                                                                  Max[0][0]
# __________________________________________________________________________________________________
# Exp (TensorFlowOpLayer)         [(None, 2048, 1024,  0           sub[0][0]
# __________________________________________________________________________________________________
# Sum (TensorFlowOpLayer)         [(None, 2048, 1024,  0           Exp[0][0]
# __________________________________________________________________________________________________
# truediv (TensorFlowOpLayer)     [(None, 2048, 1024,  0           Exp[0][0]
#                                                                  Sum[0][0]
# ==================================================================================================
# Total params: 12,264,319
# Trainable params: 12,240,761
# Non-trainable params: 23,558
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(fast_scnn, show_layer_names=True, show_shapes=True)
